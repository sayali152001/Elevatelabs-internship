# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#importing csv file
data=pd.read_csv("car_prices.csv")

# %%
#taking the overview of file
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
#checking for null values using isnull
print(data.isnull().sum())
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
#handling null values
data = data.dropna(subset=['vin'])

# %%
#has 12 missing values
data = data.dropna(subset=['sellingprice', 'saledate'])

# %%
#has more than 11k missing values
data['condition'] = data['condition'].fillna('unknown')

# %%
data['color'] = data['color'].fillna('unknown')
data['interior'] = data['interior'].fillna('unknown')

# %%
#cloumns with most missing values, so we can drop these rows
data = data.dropna(subset=['make', 'model', 'trim'])

# %%
# 13k values missing
data['body'] = data['body'].fillna('unknown')

# %%
#majority of values are missing 
data = data.drop(columns=['transmission'])

# %%
# Confirm missing values are handled
print(data.isnull().sum())
# Out:
# year             0
# make             0
# model            0
# trim             0
# body             0
# vin              0
# state            0
# condition        0
# odometer         0
# color            0
# interior         0
# seller           0
# mmr             22
# sellingprice     0
# saledate         0
# dtype: int64

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#                       vin state condition  odometer   color interior  \
# 0       5xyktca69fg566472    ca       5.0   16639.0   white    black
# ...

# %%
#checking duplicate values
duplicates = data.duplicated()

# %%
print(data[data.duplicated()])
# Out:
# Empty DataFrame
# Columns: [year, make, model, trim, body, vin, state, condition, odometer, color, interior, seller, mmr, sellingprice, saledate]
# Index: []

# %%
#removing duplicates basedon specific column
data = data.drop_duplicates(subset=['vin', 'saledate'])

# %%
#final check
print(f"Duplicates remaining: {data.duplicated().sum()}")
# Out:
# Duplicates remaining: 0

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#                       vin state condition  odometer   color interior  \
# 0       5xyktca69fg566472    ca       5.0   16639.0   white    black
# ...

# %%
#standardize column headers
data.columns = [col.strip().capitalize() for col in data.columns]

# %%
data
# Out:
#         Year    Make                Model         Trim       Body  \
# 0       2015     kia              sorento           lx        suv
# 1       2015     kia              sorento           lx        suv
# 2       2014     bmw             3 series   328i sulev      sedan
# 3       2015   volvo                  s60           t5      sedan
# 4       2014     bmw  6 series gran coupe         650i      sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     kia                 k900       luxury      sedan
# 558833  2012     ram                 2500  power wagon   crew cab
# 558834  2012     bmw                   x5    xdrive35d        suv
# 558835  2015  nissan               altima         25 s      sedan
# 558836  2014    ford                f-150          xlt  supercrew
#
#                       Vin State Condition  Odometer   Color Interior  \
# 0       5xyktca69fg566472    ca       5.0   16639.0   white    black
# ...

# %%
print(data.columns.tolist())
# Out:
# ['Year', 'Make', 'Model', 'Trim', 'Body', 'Vin', 'State', 'Condition', 'Odometer', 'Color', 'Interior', 'Seller', 'Mmr', 'Sellingprice', 'Saledate']

# %%
#checking data types
print(data.dtypes)
# Out:
# Year              int64
# Make             object
# Model            object
# Trim             object
# Body             object
# Vin              object
# State            object
# Condition        object
# Odometer        float64
# Color            object
# Interior         object
# Seller           object
# Mmr             float64
# Sellingprice    float64
# Saledate         object
# dtype: object
